# %% [markdown]
# (1)Write a Python code that takes a user's name as input and prints:
# Hello, [name]!
#
# Example:
# Input:  Rawan
# Output: Hello, Rawan!

# %%
name = input("enter your name: ")
print("hello,"+ name +"!")
# Out:
# enter your name: Ahmed
# hello,Ahmed!

# %% [markdown]
# (2)Write a Python code that takes a string input, and prints its type.
#
# Example:
# Input:  Rawan
# Output: Rawan
# Type: <class 'str'>

# %%
user = input("enter a string ")
print(user)
print(type(user))
# Out:
# enter a string Ahmed
# Ahmed
# <class 'str'>

# %% [markdown]
# (3)Write a Python code that multiply 3 numbers and print output.
#
# Example:
#
# a=4
#
# b=3
#
# c=1
#
# Output: Product: 12.

# %%
a=6
b=4
c=2
print(a+b+c)
# Out:
# 12

# %% [markdown]
# (4)Write a code to display four string input from user like “My, “Name“, “Is“, “James” as
#
# expected output
# ```
# My**Name**Is**James
#
# ```

# %%
str1 = input("enter your first string ")
str2 = input("enter your second string ")
str3 = input("enter your third string ")
str4 = input("enter your fourth string ")
print(str1+"**" +str2+"**" +str3+"**" +str4)
# Out:
# enter your first string My
# enter your second string Name
# enter your third string Is
# enter your fourth string Ahmed
# My**Name**Is**Ahmed

# %% [markdown]
# (5) Write a Python code that print:
#
# Goal Output (exact):
#
# ```
# Start -> "Middle" -> End!
#
# Done
# ```

# %%
print("Ahmed","->",'\"Ezz\"',"Eldin!")
print("Done")
# Out:
# Ahmed -> "Ezz" Eldin!
# Done

# %% [markdown]
# (6)Write a Python code that prints the following using only ONE print():
#
# Expected output:
#
# Line1
#
# Line2
#
# Line3

# %%
print("ahmed\nezz\neldin")
# Out:
# ahmed
# ezz
# eldin

# %% [markdown]
# (7)Write a Python code that takes the user's name and age as input and prints them using tab spacing.
#
# ```
# Name:    Rawan
# Age:     22
# ```

# %%
Username=input("enter your name ")
age=input("enter Your Age ")
print("Name:"+"\t"+(Username))
print("Age:"+"\t"+(age))
# Out:
# enter your name Ahmed
# enter Your Age 29
# Name:	Ahmed
# Age:	29
